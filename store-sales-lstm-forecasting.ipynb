# %% [markdown]
# # Import Libs

# %%
import numpy as np 
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/store-sales-time-series-forecasting/oil.csv
# /kaggle/input/store-sales-time-series-forecasting/sample_submission.csv
# /kaggle/input/store-sales-time-series-forecasting/holidays_events.csv
# /kaggle/input/store-sales-time-series-forecasting/stores.csv
# /kaggle/input/store-sales-time-series-forecasting/train.csv
# /kaggle/input/store-sales-time-series-forecasting/test.csv
# /kaggle/input/store-sales-time-series-forecasting/transactions.csv

# %% [markdown]
# # Import Data

# %%
train = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/train.csv')
test = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/test.csv')
stores = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/stores.csv')
oil = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/oil.csv')
holidays = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/holidays_events.csv')
transactions = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/transactions.csv')

# %% [markdown]
# # Data Preprocessing

# %%
train['date'] = pd.to_datetime(train['date'])
test['date'] = pd.to_datetime(test['date'])

# %%
# Filter data from after 2016 only
train = train[train['date'].dt.year >= 2016]
test = test[test['date'].dt.year >= 2016]

# %%
# Create a new 'holiday' column in the train dataset, marking dates that are holidays based on the holidays dataset. 
train['holiday'] = train['date'].isin(holidays['date'])

# For the test dataset, mark only the specific date '2017-08-24' as a holiday.
test['holiday'] = test['date'] == pd.to_datetime('2017-08-24')

# %%
# Extract year, month, day, and weekday from the 'date' column in the train dataset
# and create new columns for each of these components.

train['year'] = train['date'].dt.year 
train['month'] = train['date'].dt.month   
train['day'] = train['date'].dt.day        
train['weekday'] = train['date'].dt.weekday  # Extract the weekday (0 = Monday, 6 = Sunday)

# %%
# Same for Test data
test['year'] = test['date'].dt.year
test['month'] = test['date'].dt.month
test['day'] = test['date'].dt.day
test['weekday'] = test['date'].dt.weekday

# %%
# dropping date columns from train and test
train = train.drop(columns=['date'])
test = test.drop(columns=['date'])

# %% [markdown]
# > One hot encoding

# %%
# Identify all categorial columns in the train dataset 
object_cols = train.select_dtypes(include=['object']).columns

# %%
# and apply one-hot encoding to these columns in both the train and test datasets.
# The 'drop_first=True' parameter drops the first category to avoid multicollinearity.

train = pd.get_dummies(train, columns=object_cols, drop_first=True)  
test = pd.get_dummies(test, columns=object_cols, drop_first=True)

# %%
# Align the columns of the train and test datasets to ensure they have the same columns.
# Missing columns in either dataset (after alignment) are filled with zeros (fill_value=0).
# This is done to maintain consistency between the train and test sets for modeling.

train, test = train.align(test, join='left', axis=1, fill_value=0)

# %%
# Set features (X) and target (y)
# 'X' contains all columns from the train dataset except for 'sales', which is the target variable.
# 'y' contains the target variable 'sales' for the model to predict.

X = train.drop(columns=['sales'])  # Features (all columns except 'sales')
y = train['sales']  # Target variable (sales)

# %% [markdown]
# > data normalisation

# %%
# Normalising sales data with a log transformation with a skewed distribution (see EDA)
# Makes model fit better, makes data less skewed, takes care of variance. 

y_log = np.log1p(y)

# %%
# Split the data into training and validation sets- 80-20 split
# 'random_state=42' ensures same split every time the code is run (hence code is reproducible)

X_train, X_val, y_train, y_val = train_test_split(X, y_log, test_size=0.2, random_state=42)

# %%
# Scaling
# Apply MinMaxScaler to scale the features (X) and target (y) values to a range between 0 and 1
# scaling ensures no single feature or target value dominates because of its larger scale.

scaler_X = MinMaxScaler(feature_range=(0, 1))  # features
scaler_y = MinMaxScaler(feature_range=(0, 1))  # target variable

# %%
# use scaler_X to scale X_train and X_val
X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled = scaler_X.transform(X_val)

# %%
# use scaler_Y to scale Y_train and Y_val
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_val_scaled = scaler_y.transform(y_val.values.reshape(-1, 1))

# %% [markdown]
# # LSTM Preprocessing

# %%
# LSTM models expect the input data to have a specific 3D shape
# number of samples (rows), number of timesteps the number of features.
# Reshape for LSTM

X_train_scaled = X_train_scaled.reshape(X_train_scaled.shape[0], 1, X_train_scaled.shape[1])
X_val_scaled = X_val_scaled.reshape(X_val_scaled.shape[0], 1, X_val_scaled.shape[1])

# %%
train
# Out:
#               id  store_nbr     sales  onpromotion  holiday  year  month  day  \
# 1945944  1945944          1     0.000            0     True  2016      1    1
# 1945945  1945945          1     0.000            0     True  2016      1    1
# 1945946  1945946          1     0.000            0     True  2016      1    1
# 1945947  1945947          1     0.000            0     True  2016      1    1
# 1945948  1945948          1     0.000            0     True  2016      1    1
# ...          ...        ...       ...          ...      ...   ...    ...  ...
# 3000883  3000883          9   438.133            0     True  2017      8   15
# 3000884  3000884          9   154.553            1     True  2017      8   15
# 3000885  3000885          9  2419.729          148     True  2017      8   15
# 3000886  3000886          9   121.000            8     True  2017      8   15
# 3000887  3000887          9    16.000            0     True  2017      8   15
#
#          weekday  family_BABY CARE  ...  family_MAGAZINES  family_MEATS  \
# 1945944        4             False  ...             False         False
# 1945945        4              True  ...             False         False
# 1945946        4             False  ...             False         False
# 1945947        4             False  ...             False         False
# 1945948        4             False  ...             False         False
# ...          ...               ...  ...               ...           ...
# 3000883        1             False  ...             False         False
# 3000884        1             False  ...             False         False
# 3000885        1             False  ...             False         False
# 3000886        1             False  ...             False         False
# 3000887        1             False  ...             False         False
#
#          family_PERSONAL CARE  family_PET SUPPLIES  \
# 1945944                 False                False
# 1945945                 False                False
# 1945946                 False                False
# 1945947                 False                False
# 1945948                 False                False
# ...                       ...                  ...
# 3000883                 False                False
# 3000884                 False                False
# 3000885                 False                False
# 3000886                 False                False
# 3000887                 False                False
#
#          family_PLAYERS AND ELECTRONICS  family_POULTRY  \
# 1945944                           False           False
# 1945945                           False           False
# 1945946                           False           False
# 1945947                           False           False
# 1945948                           False           False
# ...                                 ...             ...
# 3000883                           False            True
# 3000884                           False           False
# 3000885                           False           False
# 3000886                           False           False
# 3000887                           False           False
#
#          family_PREPARED FOODS  family_PRODUCE  \
# 1945944                  False           False
# 1945945                  False           False
# 1945946                  False           False
# 1945947                  False           False
# 1945948                  False           False
# ...                        ...             ...
# 3000883                  False           False
# 3000884                   True           False
# 3000885                  False            True
# 3000886                  False           False
# 3000887                  False           False
#
#          family_SCHOOL AND OFFICE SUPPLIES  family_SEAFOOD
# 1945944                              False           False
# 1945945                              False           False
# 1945946                              False           False
# 1945947                              False           False
# 1945948                              False           False
# ...                                    ...             ...
# 3000883                              False           False
# 3000884                              False           False
# 3000885                              False           False
# 3000886                               True           False
# 3000887                              False            True
#
# [1054944 rows x 41 columns]

# %% [markdown]
# # Model Training

# %%
# Instantiate Model
model = Sequential()

# %% [markdown]
# > LSTM Layer

# %%
# Add an LSTM layer with 50 units and specify the input shape
# shape 1 is number of timesteps
# shape 2 is number of features for each timestep

model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))

# %% [markdown]
# > Dropout Layer

# %%
# Drop 20% of the LSTM units to prevent overfitting - Regularization technique
model.add(Dropout(0.2))

# %% [markdown]
# > Repeat the steps

# %%
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

# %% [markdown]
# > output layer

# %%
# Add a Dense output layer with 1 unit for the final prediction
model.add(Dense(units=1))

# %%
# Compile the model with the Adam optimizer and mean squared error as the loss function
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs = 100
retrain_recent_data = True
retrain_epochs = 20

# %%
# Train the model on the training data and validate it using the validation data
# The model will be trained for the specified number of epochs and with a batch size of 64

history = model.fit(X_train_scaled, y_train_scaled, epochs=epochs, batch_size=64, 
                    validation_data=(X_val_scaled, y_val_scaled), verbose=1)
# Out:
# Epoch 1/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 0.0120 - val_loss: 0.0076
# Epoch 2/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0079 - val_loss: 0.0069
# Epoch 3/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 4/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0071 - val_loss: 0.0064
# Epoch 5/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 6/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 7/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 8/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 9/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 10/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 11/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 12/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 13/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 14/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 15/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 16/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 17/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 18/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 19/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 20/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 21/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 22/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 23/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 24/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 25/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 26/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 27/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 28/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 29/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 30/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 31/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 32/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 33/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 34/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 35/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 36/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 37/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 38/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 39/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 40/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 41/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 42/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 43/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 44/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 45/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 46/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 47/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 48/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 49/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 50/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 51/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 52/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 53/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 54/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 55/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 56/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 57/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 58/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 59/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 60/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 61/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 62/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 63/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 64/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 65/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 66/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 67/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 68/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 69/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 70/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 71/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 72/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 73/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 74/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 75/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 76/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 77/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 78/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 79/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 80/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 81/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 82/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 83/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 84/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 85/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 86/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 87/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 88/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 89/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 90/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 91/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 92/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 93/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 94/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 95/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 96/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 97/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 98/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 99/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 100/100
# 13187/13187 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 0.0046 - val_loss: 0.0041

# %%
if retrain_recent_data:
    retrain_history = model.fit(X_val_scaled, y_val_scaled, epochs=retrain_epochs, batch_size=64, verbose=1)
# Out:
# Epoch 1/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0047
# Epoch 2/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0047
# Epoch 3/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 4/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 5/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0047
# Epoch 6/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 7/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 8/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 9/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 10/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 11/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 12/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 13/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 14/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 15/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 16/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 17/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 18/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 19/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046
# Epoch 20/20
# 3297/3297 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0046

# %% [markdown]
# # Predict

# %% [markdown]
# > Validation Dataset

# %%
# Make predictions on the validation data
y_val_pred_scaled = model.predict(X_val_scaled)
# Out:
# 6594/6594 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step

# %%
# Inverse transform the predicted values back to the original scale
# The predictions and actual target values (y_val_scaled) are scaled, so we need to convert them back
y_val_pred = scaler_y.inverse_transform(y_val_pred_scaled)
y_val = scaler_y.inverse_transform(y_val_scaled)

# %%
# Evaluate the model's performance using Mean Squared Error (MSE)
mse = mean_squared_error(y_val, y_val_pred)
print(f'Validation MSE: {mse}')
# Out:
# Validation MSE: 0.5465549446401388

# %% [markdown]
# > Test Dataset

# %%
# Prepare the test data by dropping the 'sales' column (since we want to predict it)
X_test = test.drop(columns=['sales'])

# %%
# Scale the test data using the previously fitted scaler (used for training data)
X_test_scaled = scaler_X.transform(X_test)

# %%
# Reshape the test data to fit the LSTM input format (samples, timesteps, features)
X_test_scaled = X_test_scaled.reshape(X_test_scaled.shape[0], 1, X_test_scaled.shape[1])

# %%
# Make predictions on the test data using the trained model
test_predictions_scaled = model.predict(X_test_scaled)
# Out:
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# Convert the predicted 'sales' back to the original scale using the inverse transformation
test['sales'] = np.expm1(scaler_y.inverse_transform(test_predictions_scaled))

# %%
# Handle any negative predictions by setting them to 0 (since sales can't be negative)
test['sales'] = np.where(test['sales'] < 0, 0, test['sales'])

# %%
# Save the submission DataFrame to a CSV file for submission
submission = test[['id', 'sales']]
submission
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Save the submission DataFrame to a CSV file for submission
# ----> 2 submission = test[['id', 'sales']]
#       3 submission
#
# NameError: name 'test' is not defined

# %%
submission.to_csv('/Users/sanchalisinghal/Desktop/KGGLE/submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 submission.to_csv('/Users/sanchalisinghal/Desktop/KGGLE/submission.csv', index=False)
#
# NameError: name 'submission' is not defined
